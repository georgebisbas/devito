# %% [markdown]
# # Verification of Elastic wave equation implementation on a staggered grid using the method of manufactured solutions.
# This is a first attempt at implemenenting the elastic wave equation as described in:
#
# [1] Jean Virieux (1986). ”P-SV wave propagation in heterogeneous media: Velocity‐stress finite‐difference method.” GEOPHYSICS, 51(4), 889-901. https://doi.org/10.1190/1.1442147
#
# The current version actually attempts to mirror the FDELMODC implementation by Jan Thorbecke:
#
# [2] https://janth.home.xs4all.nl/Software/fdelmodcManual.pdf
#
# ## Explosive source
#
# We will first attempt to replicate the explosive source test case described in [1], Figure 4. We start by defining the source signature $g(t)$, the derivative of a Gaussian pulse, given by Eq 4:
#
# $$g(t) = -2 \alpha(t - t_0)e^{-\alpha(t-t_0)^2}$$

# %%
from devito import *
from examples.seismic.source import WaveletSource, RickerSource, TimeAxis
from examples.seismic import plot_image
import numpy as np

from sympy import init_printing, latex
init_printing(use_latex=True)

# Initial grid: 1km x 1km, with spacing 100m
extent = (2000., 2000.)
shape = (301, 301)
x = SpaceDimension(name='x', spacing=Constant(name='h_x', value=extent[0]/(shape[0]-1)))
z = SpaceDimension(name='z', spacing=Constant(name='h_z', value=extent[1]/(shape[1]-1)))
grid = Grid(extent=extent, shape=shape, dimensions=(x, z))

class DGaussSource(WaveletSource):
    
    def wavelet(self, f0, t):
        a = 0.004
        return -2.*a*(t - 1/f0) * np.exp(-a * (t - 1/f0)**2)

# Timestep size from Eq. 7 with V_p=6000. and dx=100
t0, tn = 0., 600.
dt = (10. / np.sqrt(2.)) / 6.
time_range = TimeAxis(start=t0, stop=tn, step=dt)

src = RickerSource(name='src', grid=grid, f0=0.01, time_range=time_range)
src.coordinates.data[:] = [1000., 1000.]
#src.show()

so = 2 # space order
vx  = TimeFunction(name='vx' , grid=grid, staggered = x,    space_order=so)
vz  = TimeFunction(name='vz' , grid=grid, staggered = z,    space_order=so)
txx = TimeFunction(name='txx', grid=grid, staggered = NODE, space_order=so)
tzz = TimeFunction(name='tzz', grid=grid, staggered = NODE, space_order=so)
txz = TimeFunction(name='txz', grid=grid, staggered=(x, z), space_order=so) 

# Now let's try and create the staggered updates
t = grid.stepping_dim
time = grid.time_dim

# We need some initial conditions
V_p = 4.0
V_s = 1.0
density = 3.

# The source injection term
src_xx = src.inject(field=txx.forward, expr=src)
src_zz = src.inject(field=tzz.forward, expr=src)

#c1 = 9.0/8.0;
#c2 = -1.0/24.0;

# Thorbecke's parameter notation
cp2 = V_p*V_p
cs2 = V_s*V_s
ro = 1/density

mu = cs2*ro
l = (cp2*ro - 2*mu)

# fdelmodc reference implementation
u_vx = Eq(vx.forward, vx - dt*ro*(txx.dx + txz.dz))
u_vz = Eq(vz.forward, vz - ro*dt*(txz.dx + tzz.dz))
u_txx = Eq(txx.forward, txx - (l+2*mu)*dt * vx.forward.dx -  l*dt * vz.forward.dz)
u_tzz = Eq(tzz.forward, tzz - (l+2*mu)*dt * vz.forward.dz -  l*dt * vx.forward.dx)
u_txz = Eq(txz.forward, txz - mu*dt * (vx.forward.dz + vz.forward.dx))

op = Operator([u_vx, u_vz, u_txx, u_tzz, u_txz] + src_xx + src_zz)

# Reset the fields
vx.data[:] = 0.
vz.data[:] = 0.
txx.data[:] = 0.
tzz.data[:] = 0.
txz.data[:] = 0.

op()

# Let's see what we got....
plot_image(vx.data[0], vmin=-.5*1e-2, vmax=.5*1e-2, cmap="seismic")
plot_image(vz.data[0], vmin=-.5*1e-2, vmax=.5*1e-2, cmap="seismic")
plot_image(txx.data[0], vmin=-.5*1e-2, vmax=.5*1e-2, cmap="seismic")
plot_image(tzz.data[0], vmin=-.5*1e-2, vmax=.5*1e-2, cmap="seismic")
plot_image(txz.data[0], vmin=-.5*1e-2, vmax=.5*1e-2, cmap="seismic")

# %% [markdown]
# # Analytical solution definition and  Corresponding source

# %%
# Initial grid: 1km x 1km, with spacing 100m
extent = (2000., 2000.)
shape = (310, 310)
x = SpaceDimension(name='x', spacing=Constant(name='h_x', value=extent[0]/(shape[0]-1)))
z = SpaceDimension(name='z', spacing=Constant(name='h_z', value=extent[1]/(shape[1]-1)))
grid = Grid(extent=extent, shape=shape, dimensions=(x, z))#x, z = grid.dimensions
t = grid.time_dim

from sympy import cos, sin, exp, pprint, sqrt, sin, sinc
import sympy

u, v, w, c = sympy.symbols('u v w c')
sol = sin(2*np.pi*u) * sin(4*np.pi*v)* sin(2*np.pi*w)

# Corresponding source
source = sol.diff(w, w) - sol.diff(u, u) - sol.diff(v, v)

sol = sol.subs({u: x*x.spacing, v: z*z.spacing, w: t*t.spacing})
source = source.subs({u: x*x.spacing, v: z*z.spacing, w: t*t.spacing})

so = 2
so2 = 0
to = 1

vx  = TimeFunction(name='vx',  grid=grid, staggered=x,      space_order=so)
vz  = TimeFunction(name='vz',  grid=grid, staggered=z,      space_order=so)
vz  = TimeFunction(name='vz',  grid=grid, staggered=z,      space_order=so)
txx = TimeFunction(name='txx', grid=grid, staggered=NODE,   space_order=so)
tzz = TimeFunction(name='tzz', grid=grid, staggered=NODE,   space_order=so)
txz = TimeFunction(name='txz', grid=grid, staggered=(x, z), space_order=so)
    
# Wave equation
vx_true  = TimeFunction(name='vx_true' , grid=grid, staggered=x,      space_order=so)
vz_true  = TimeFunction(name='vz_true' , grid=grid, staggered=z,      space_order=so)
txx_true = TimeFunction(name='txx_true', grid=grid, staggered=NODE,   space_order=so)
tzz_true = TimeFunction(name='tzz_true', grid=grid, staggered=NODE,   space_order=so)
txz_true = TimeFunction(name='txz_true', grid=grid, staggered=(x, z), space_order=so)
    
src_vx  = TimeFunction(name='src_vx' , grid=grid, staggered=x,     space_order=so)
src_vz  = TimeFunction(name='src_vz' , grid=grid, staggered=z,      space_order=so)
src_txx = TimeFunction(name='src_txx', grid=grid, staggered=NODE,   space_order=so)
src_tzz = TimeFunction(name='src_tzz', grid=grid, staggered=NODE,   space_order=so)
src_txz = TimeFunction(name='src_txz', grid=grid, staggered=(x, z), space_order=so)
    
# fdelmodc reference implementation
wave_vx  = Eq(vx.forward,  vx - dt*ro*(txx.dx + txz.dz)         + src_vx              )
wave_vz  = Eq(vz.forward,  vz - ro*dt*(txz.dx + tzz.dz)            + src_vz            )
wave_txx = Eq(txx.forward, txx - (l+2*mu)*dt * vx.forward.dx -  l*dt * vz.forward.dz + src_txx )
wave_tzz = Eq(tzz.forward, tzz - (l+2*mu)*dt * vz.forward.dz -  l*dt * vx.forward.dx + src_tzz   )
wave_txz = Eq(txz.forward, txz - mu*dt * (vx.forward.dz + vz.forward.dx)   + src_txz   )

true_eqq_vx  = Eq(vx_true, sol)
true_eqq_vz  = Eq(vz_true, sol)
true_eqq_txx = Eq(txx_true, sol)
true_eqq_txz = Eq(txz_true, sol)
true_eqq_tzz = Eq(tzz_true, sol)

src_eq_vx  = Eq( src_vx , source)
src_eq_vz  = Eq( src_vz , source)
src_eq_txx = Eq( src_txx, source)
src_eq_txz = Eq( src_txz, source)
src_eq_tzz = Eq( src_tzz, source)


## from devito import configuration
configuration["log-level"] = "ERROR"
h = .00125

vx_0 = Eq(vx , sol )
vx_1 = Eq(vx.subs(t, 1), sol.subs(t, 1))

op = Operator([vx_1,true_eqq_vx, src_eq_vx, wave_vx], subs=({t.spacing: .1*h, x.spacing:h, z.spacing:h}))
op.apply(t_m=0, t_M=600)
# Out:
# PerformanceSummary([('section0',
#   PerfEntry(time=1.6545240000000008, gflopss=0.0, gpointss=0.0, oi=0.0, ops=0, itershapes=[]))])

# %% [markdown]
# # Elastic wave equation

# %%
def get_solution_elastic(size, space_order):
    clear_cache()
    import sympy
    from sympy import cos, sin, exp, pprint, sqrt, sin, sinc
    
    
    # Initial grid: 1km x 1km, with spacing 100m
    extent = (2000., 2000.)
    shape = (size, size)
    x = SpaceDimension(name='x', spacing=Constant(name='h_x', value=extent[0]/(shape[0]-1)))
    z = SpaceDimension(name='z', spacing=Constant(name='h_z', value=extent[1]/(shape[1]-1)))
    grid = Grid(extent=extent, shape=shape, dimensions=(x, z))

    # Grid
    h = 1./(size - 1)
    
    # Timestep size from Eq. 7 with V_p=6000. and dx=100
    #t0, tn = 0., 600.
    #dt = (10. / np.sqrt(2.)) / 180.
    
    #time_range = TimeAxis(start=t0, stop=tn, step=dt)
    #src = RickerSource(name='src', grid=grid, f0=0.01, time_range=time_range)
    #src.coordinates.data[:] = [1000., 1000.]


    # Now let's try and create the staggered updates
    t = grid.stepping_dim
    time = grid.time_dim

    # We need some initial conditions
    V_p = 4.0
    V_s = 1.0
    density = 3.

    # The source injection term
    #src_xx = src.inject(field=txx.forward, expr=src)
    #src_zz = src.inject(field=tzz.forward, expr=src)

    # Thorbecke's parameter notation
    cp2 = V_p*V_p
    cs2 = V_s*V_s
    ro = 1/density
    mu = cs2*ro
    l = (cp2*ro - 2*mu)

    # fdelmodc reference implementation
    #u_vx = Eq(vx.forward, vx - dt*ro*(txx.dx + txz.dz))
    #u_vz = Eq(vz.forward, vz - ro*dt*(txz.dx + tzz.dz))
    #u_txx = Eq(txx.forward, txx - (l+2*mu)*dt * vx.forward.dx -  l*dt * vz.forward.dz)
    #u_tzz = Eq(tzz.forward, tzz - (l+2*mu)*dt * vz.forward.dz -  l*dt * vx.forward.dx)
    #u_txz = Eq(txz.forward, txz - mu*dt * (vx.forward.dz + vz.forward.dx))


    # Model
    # Timestep size from Eq. 7 with V_p=6000. and dx=100
    t0, tn = 0., 100.
    #dt = (10. / np.sqrt(2.)) / 40.

    dt= 1.6
    time_range = TimeAxis(start=t0, stop=tn, step=dt)
    src = RickerSource(name='src', grid=grid, f0=0.01, time_range=time_range)
    src.coordinates.data[:] = [1000., 1000.]
    
    nt = 64;   # FIX ME
    
    # Now we create the velocity and pressure fields
    so = space_order
    so2 = so
    #to = 2
    #to2 = 2
    
    vx  = TimeFunction(name='vx',  grid=grid, staggered=x,      space_order=so,  save=nt)
    vz  = TimeFunction(name='vz',  grid=grid, staggered=z,      space_order=so,  save=nt)
    txx = TimeFunction(name='txx', grid=grid, staggered=NODE,   space_order=so,  save=nt)
    tzz = TimeFunction(name='tzz', grid=grid, staggered=NODE,   space_order=so,  save=nt)
    txz = TimeFunction(name='txz', grid=grid, staggered=(x, z), space_order=so,  save=nt)
    
    # The source injection term
    src_xx = src.inject(field=txx.forward, expr=src)
    src_zz = src.inject(field=tzz.forward, expr=src)
    
    # Wave equation
    vx_true  = TimeFunction(name='vx_true' , grid=grid, staggered=x,      space_order=so2,  save=nt)
    vz_true  = TimeFunction(name='vz_true' , grid=grid, staggered=z,      space_order=so2,  save=nt)
    txx_true = TimeFunction(name='txx_true', grid=grid, staggered=NODE,   space_order=so2,  save=nt)
    tzz_true = TimeFunction(name='tzz_true', grid=grid, staggered=NODE,   space_order=so2,  save=nt)
    txz_true = TimeFunction(name='txz_true', grid=grid, staggered=(x, z), space_order=so2,  save=nt)
     
    src_vx  = TimeFunction(name='src_vx' , grid=grid, staggered=x,     space_order=so2,  save=nt)
    src_vz  = TimeFunction(name='src_vz' , grid=grid, staggered=z,      space_order=so2, save=nt)
    src_txx = TimeFunction(name='src_txx', grid=grid, staggered=NODE,   space_order=so2, save=nt)
    src_tzz = TimeFunction(name='src_tzz', grid=grid, staggered=NODE,   space_order=so2, save=nt)
    src_txz = TimeFunction(name='src_txz', grid=grid, staggered=(x, z), space_order=so2, save=nt)
    
    
    ###################input = ###########################################################
    #shape = (size, size)

    #x = SpaceDimension(name='x', spacing=Constant(name='h_x', value=extent[0]/(shape[0]-1)))
    #z = SpaceDimension(name='z', spacing=Constant(name='h_z', value=extent[1]/(shape[1]-1)))
    #grid = Grid(extent=extent, shape=shape, dimensions=(x, z))

    t = time

    
    u, v, w, c = sympy.symbols('u v w c')
    #sol = 1e1*sin(2*np.pi*u) * sin(4*np.pi*v)* sin(6*np.pi*w)
    sol = (10*sin(6*np.pi*w) * exp(-(u - .5)**2/.015 - (v-.5)**2/.015) +
           10*sin(4*np.pi*w) *exp(-(u - .45)**2/.0025 - (v-.65)**2/.0025)-
           50*sin(8*np.pi*w) *exp(-(u - .65)**2/.0025 - (v-.45)**2/.0015)+
           10*sin(6*np.pi*w) * exp(-(u - .45)**2/.0015 - (v-.45)**2/.0025)-
           50*sin(6*np.pi*w) * exp(-(u - .65)**2/.0027 - (v-.65)**2/.0021))
    #print(sol)

    # Corresponding source
    source = sol.diff(w, w) - sol.diff(u, u) - sol.diff(v, v)
    sol = sol.subs({u: x*x.spacing, v: z*z.spacing, w: t*t.spacing})
    source = source.subs({u: x*x.spacing, v: z*z.spacing, w: t*t.spacing})

    #################################################################################
    
    # fdelmodc reference implementation
    wave_vx  = Eq(vx.forward,  vx - dt*ro*(txx.dx + txz.dz)                  )
    wave_vz  = Eq(vz.forward,  vz - ro*dt*(txz.dx + tzz.dz)                  )
    wave_txx = Eq(txx.forward, txx - (l+2*mu)*dt * vx.forward.dx -  l*dt * vz.forward.dz )
    wave_tzz = Eq(tzz.forward, tzz - (l+2*mu)*dt * vz.forward.dz -  l*dt * vx.forward.dx   )
    wave_txz = Eq(txz.forward, txz - mu*dt * (vx.forward.dz + vz.forward.dx)   )

    true_eqq_vx  = Eq(vx_true, sol)
    true_eqq_vz  = Eq(vz_true, sol)
    true_eqq_txx = Eq(txx_true, sol)
    true_eqq_txz = Eq(txz_true, sol)
    true_eqq_tzz = Eq(tzz_true, sol)
    
    src_eq_vx  = Eq( src_vx , source)
    src_eq_vz  = Eq( src_vz , source)
    src_eq_txx = Eq( src_txx, source)
    src_eq_txz = Eq( src_txz, source)
    src_eq_tzz = Eq( src_tzz, source)
    
    
    configuration["log-level"] = "ERROR"
    
    vx_1 = Eq(vx.subs(t, 1), sol.subs(t, 1))
    vz_1 = Eq(vz.subs(t, 1), sol.subs(t, 1))
    txx_1 = Eq(txx.subs(t, 1), sol.subs(t, 1))
    txz_1 = Eq(txz.subs(t, 1), sol.subs(t, 1))
    tzz_1 = Eq(tzz.subs(t, 1), sol.subs(t, 1))
      
    #import matplotlib.pyplot as plt
    #plt.figure()
    #plt.subplot(141)
    #plt.imshow(vx.data[(nt-3), :, :], vmin=-.1, vmax=.1, cmap="seismic")
    #plt.subplot(142)
    #plt.imshow(vx_true.data[(nt-3), :, :], vmin=-.1, vmax=.1, cmap="seismic")
    #plt.subplot(143)
    #plt.imshow(vx.data[(nt-3), :, :] - vx_true.data[(nt-3), :, :], vmin=-.1, vmax=.1, cmap="seismic")
    #plt.show()
    
    #op = Operator([vx_1,true_eqq_vx, src_eq_vx, wave_vx]+ src_xx + src_zz, subs=({t.spacing: .1*h, x.spacing:h, z.spacing:h}))
    op = Operator([vx_1,vz_1,txx_1,txz_1,tzz_1,
                   wave_vx, wave_vz, wave_txx, wave_tzz, wave_txz,
                   true_eqq_vx, true_eqq_vz, true_eqq_txx,true_eqq_txz,true_eqq_tzz,
                   src_eq_vx,src_eq_vz,src_eq_txx,src_eq_txz,src_eq_tzz] + src_xx + src_zz)

    
    #op = Operator([
     #   vx_1,vz_1,txx_1,txz_1,tzz_1,
      #             true_eqq_vx, true_eqq_vz,true_eqq_txx,true_eqq_txz,true_eqq_tzz,
       #            src_eq_vx,src_eq_vz,src_eq_txx,src_eq_txz,src_eq_tzz, 
        #           wave_vx, wave_vz, wave_txx, wave_txz, wave_tzz] + src_xx + src_zz, subs=({t.spacing: .1*h, x.spacing:h, z.spacing:h}))
    
    # Reset the fields
    #vx.data[:] = 0.
    #vz.data[:] = 0.
    #txx.data[:] = 0.
    #tzz.data[:] = 0.
    #txz.data[:] = 0.
    
    op.apply()
   
    error1 = np.linalg.norm(vx.data[(nt-3), :, :].reshape(-1) -
                            vx_true.data[(nt-3), :, :].reshape(-1), 2)*h
    error2 = np.linalg.norm(vz.data[(nt-3), :, :].reshape(-1) -
                            vz_true.data[(nt-3), :, :].reshape(-1), 2)*h
    error3 = np.linalg.norm(txx.data[(nt-3), :, :].reshape(-1) -
                            txx_true.data[(nt-3), :, :].reshape(-1), 2)*h
    error4 = np.linalg.norm(txz.data[(nt-3), :, :].reshape(-1) -
                           txz_true.data[(nt-3), :, :].reshape(-1), 2)*h
    error5 = np.linalg.norm(tzz.data[(nt-3), :, :].reshape(-1) -
                           tzz_true.data[(nt-3), :, :].reshape(-1), 2)*h
    
    error = (error1 + error2 + error3 + error4 +error5) / 5
    print("Size = %d and space_order = %d, for h = %f and dt= %2.2e ms error is %2.4e" % (size, so, h, dt, error))
     
    #import matplotlib.pyplot as plt
    #plt.figure()
    #plt.subplot(131)
    #plt.imshow(vx.data[(nt-3), :, :], vmin=-.1, vmax=.1, cmap="seismic")
    #plt.subplot(132)
    #plt.imshow(vx_true.data[(nt-3), :, :], vmin=-.1, vmax=.1, cmap="seismic")
    #plt.subplot(133)
    #plt.imshow(vx.data[(nt-3), :, :] - vx_true.data[(nt-3), :, :], vmin=-.1, vmax=.1, cmap="seismic")
    #plt.show()

    return error

# %% [markdown]
# # MMS

# %%
size = [51,61, 75, 101, 151, 201, 301, 401]
so = [2,4,6,8,10,12]
error = np.zeros((len(size), len(so)))
# hh = [4*h for h in hh]
for i, s in enumerate(size):
    for j, sso in enumerate(so):
        error[i, j] = get_solution_elastic(s, sso)
# Out:
# Size = 51 and space_order = 2, for h = 0.020000 and dt= 1.60e+00 ms error is 8.0088e-02
# Size = 51 and space_order = 4, for h = 0.020000 and dt= 1.60e+00 ms error is 7.7187e-02
# Size = 51 and space_order = 6, for h = 0.020000 and dt= 1.60e+00 ms error is 7.5341e-02
# Size = 51 and space_order = 8, for h = 0.020000 and dt= 1.60e+00 ms error is 7.4242e-02
# Size = 51 and space_order = 10, for h = 0.020000 and dt= 1.60e+00 ms error is 7.3532e-02
# Size = 51 and space_order = 12, for h = 0.020000 and dt= 1.60e+00 ms error is 7.3039e-02
# Size = 61 and space_order = 2, for h = 0.016667 and dt= 1.60e+00 ms error is 6.3731e-02
# Size = 61 and space_order = 4, for h = 0.016667 and dt= 1.60e+00 ms error is 5.8273e-02
# Size = 61 and space_order = 6, for h = 0.016667 and dt= 1.60e+00 ms error is 5.6052e-02
# Size = 61 and space_order = 8, for h = 0.016667 and dt= 1.60e+00 ms error is 5.4929e-02
# Size = 61 and space_order = 10, for h = 0.016667 and dt= 1.60e+00 ms error is 5.4271e-02
# Size = 61 and space_order = 12, for h = 0.016667 and dt= 1.60e+00 ms error is 5.3845e-02
# Size = 75 and space_order = 2, for h = 0.013514 and dt= 1.60e+00 ms error is 4.4250e-02
# Size = 75 and space_order = 4, for h = 0.013514 and dt= 1.60e+00 ms error is 3.8944e-02
# Size = 75 and space_order = 6, for h = 0.013514 and dt= 1.60e+00 ms error is 3.7380e-02
# Size = 75 and space_order = 8, for h = 0.013514 and dt= 1.60e+00 ms error is 3.6710e-02
# Size = 75 and space_order = 10, for h = 0.013514 and dt= 1.60e+00 ms error is 3.6359e-02
# Size = 75 and space_order = 12, for h = 0.013514 and dt= 1.60e+00 ms error is 3.6151e-02
# Size = 101 and space_order = 2, for h = 0.010000 and dt= 1.60e+00 ms error is 2.3197e-02
# Size = 101 and space_order = 4, for h = 0.010000 and dt= 1.60e+00 ms error is 2.0842e-02
# Size = 101 and space_order = 6, for h = 0.010000 and dt= 1.60e+00 ms error is 2.0360e-02
# Size = 101 and space_order = 8, for h = 0.010000 and dt= 1.60e+00 ms error is 2.0192e-02
# Size = 101 and space_order = 10, for h = 0.010000 and dt= 1.60e+00 ms error is 2.0115e-02
# Size = 101 and space_order = 12, for h = 0.010000 and dt= 1.60e+00 ms error is 2.0073e-02
# Size = 151 and space_order = 2, for h = 0.006667 and dt= 1.60e+00 ms error is 9.7556e-03
# Size = 151 and space_order = 4, for h = 0.006667 and dt= 1.60e+00 ms error is 9.2366e-03
# Size = 151 and space_order = 6, for h = 0.006667 and dt= 1.60e+00 ms error is 9.1552e-03
# Size = 151 and space_order = 8, for h = 0.006667 and dt= 1.60e+00 ms error is 9.1298e-03
# Size = 151 and space_order = 10, for h = 0.006667 and dt= 1.60e+00 ms error is 9.1183e-03
# Size = 151 and space_order = 12, for h = 0.006667 and dt= 1.60e+00 ms error is 9.1118e-03
# Size = 201 and space_order = 2, for h = 0.005000 and dt= 1.60e+00 ms error is 5.4360e-03
# Size = 201 and space_order = 4, for h = 0.005000 and dt= 1.60e+00 ms error is 5.2471e-03
# Size = 201 and space_order = 6, for h = 0.005000 and dt= 1.60e+00 ms error is 5.2199e-03
# Size = 201 and space_order = 8, for h = 0.005000 and dt= 1.60e+00 ms error is 5.2109e-03
# Size = 201 and space_order = 10, for h = 0.005000 and dt= 1.60e+00 ms error is 5.2065e-03
# Size = 201 and space_order = 12, for h = 0.005000 and dt= 1.60e+00 ms error is 5.2038e-03
# Size = 301 and space_order = 2, for h = 0.003333 and dt= 1.60e+00 ms error is 2.4314e-03
# Size = 301 and space_order = 4, for h = 0.003333 and dt= 1.60e+00 ms error is 2.3806e-03
# Size = 301 and space_order = 6, for h = 0.003333 and dt= 1.60e+00 ms error is 2.3729e-03
# Size = 301 and space_order = 8, for h = 0.003333 and dt= 1.60e+00 ms error is 2.3699e-03
# Size = 301 and space_order = 10, for h = 0.003333 and dt= 1.60e+00 ms error is 2.3683e-03
# Size = 301 and space_order = 12, for h = 0.003333 and dt= 1.60e+00 ms error is 2.3674e-03
# Size = 401 and space_order = 2, for h = 0.002500 and dt= 1.60e+00 ms error is 1.3866e-03
# Size = 401 and space_order = 4, for h = 0.002500 and dt= 1.60e+00 ms error is 1.3648e-03
# Size = 401 and space_order = 6, for h = 0.002500 and dt= 1.60e+00 ms error is 1.3611e-03
# Size = 401 and space_order = 8, for h = 0.002500 and dt= 1.60e+00 ms error is 1.3596e-03
# Size = 401 and space_order = 10, for h = 0.002500 and dt= 1.60e+00 ms error is 1.3587e-03
# Size = 401 and space_order = 12, for h = 0.002500 and dt= 1.60e+00 ms error is 1.3582e-03

# %%
import matplotlib.pyplot as plt
col = ['-ob', '-or', '-og', '-ok', '-oc', '-ob', '-or',]
col_2 = ['--ob', '--or', '--og', '--ok', '--oc','--ob', '--or']
#hh = [0.02, 0.01, 0.005, 0.00025]
#hh = [1, .5, .25, .125]
#hh = [4*h for h in hh]
#hh = [0.02, 0.01, 0.005, 0.0025, 0.00125]
hh = [0.08, 0.04, 0.02, 0.01, 0.005, 0.0025, 0.00125]
hh = [0.1*h for h in hh]


plt.figure(figsize=(15, 10))
for j, sso in enumerate(so):
    plt.loglog(hh[1:3], hh[1]**so[j]*error[1:3, j]/error[1, j], col[j])
    plt.loglog(hh[1:3], [h**so[j] for h in hh][1:3], col_2[j])

    #plt.loglog(hh[1:3], error[:, 3])
    #plt.loglog(hh[1:3], [h**so[3] for h in hh])

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 5))
im = plt.pcolormesh(error, cmap='viridis')
fig.colorbar(im)
plt.title('Convergence')
plt.ylabel('Grid size')
plt.xlabel('Space order')
plt.set_xlim(0.5, 4.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-951df53a4ef1> in <module>
#       6 plt.ylabel('Grid size')
#       7 plt.xlabel('Space order')
# ----> 8 plt.set_xlim(0.5, 4.5)
#       9
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xlim'
